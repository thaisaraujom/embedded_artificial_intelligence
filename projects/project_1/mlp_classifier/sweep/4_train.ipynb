# %% [markdown]
# # Your First Image Classifier: Using MLP to Classify Images
# # Train

# %% [markdown]
# The purpose of this dataset is to correctly classify an image as containing a dog, cat, or panda.
# Containing only 3,000 images, the Animals dataset is meant to be another **introductory** dataset
# that we can quickly train a MLP model and obtain a comparative results.
#
#
# Let's take the following steps:
#
# 1. Encoding target variable
# 2. Training the MLP model
# 3. Export the model and the encoder object
#
# <center><img width="900" src="https://drive.google.com/uc?export=view&id=1haMB_Zt6Et9q9sPHxfuR4g3FT5QRXlTI"></center>

# %% [markdown]
# ## Step 01: Setup

# %% [markdown]
# Start out by installing the experiment tracking library and setting up your free W&B account:
#
#
# *   **pip install wandb** – Install the W&B library
# *   **import wandb** – Import the wandb library
# *   **wandb login** – Login to your W&B account so you can log all your metrics in one place

# %%
# !pip install wandb -qU

# %%
# a Python package for tracking the carbon emissions produced by various
# kinds of computer programs, from straightforward algorithms to deep neural networks.
# !pip install codecarbon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: codecarbon in /usr/local/lib/python3.7/dist-packages (2.1.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.7/dist-packages (from codecarbon) (8.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from codecarbon) (1.3.5)
# Requirement already satisfied: arrow in /usr/local/lib/python3.7/dist-packages (from codecarbon) (1.2.3)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (from codecarbon) (0.18.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.7/dist-packages (from codecarbon) (11.4.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from codecarbon) (5.4.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from codecarbon) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from codecarbon) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from arrow->codecarbon) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from arrow->codecarbon) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->codecarbon) (2022.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->codecarbon) (1.21.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (2022.9.24)

# %% [markdown]
# ### Import Packages

# %%
# import the necessary packages
from imutils import paths
import logging
import os
import cv2
import numpy as np
import joblib
from codecarbon import EmissionsTracker
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import fbeta_score, precision_score, recall_score, accuracy_score
import wandb

# %%
wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: thaisaraujom. Use `wandb login --relogin` to force relogin
# True

# %%
# configure logging
# reference for a logging obj
logger = logging.getLogger()

# set level of logging
logger.setLevel(logging.INFO)

# create handlers
c_handler = logging.StreamHandler()
c_format = logging.Formatter(fmt="%(asctime)s %(message)s",datefmt='%d-%m-%Y %H:%M:%S')
c_handler.setFormatter(c_format)

# add handler to the logger
logger.handlers[0] = c_handler

# %% [markdown]
# ## Step 02 Basic configuration and download artifacts

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
  "project_name": "mlp_classifier",
  "train_feature_artifact": "train_x:latest",
  "train_target_artifact": "train_y:latest",
  "val_feature_artifact": "val_x:latest",
  "val_target_artifact": "val_y:latest",
  "neighbors": 1,
  "jobs": -1,
  "encoder": "target_encoder",
  "inference_model": "model"
}

# %%
# open the W&B project created in the Fetch step
run = wandb.init(entity="thaisaraujom",project=args["project_name"], job_type="Train")

logger.info("Downloading the train and validation data")
# train x
train_x_artifact = run.use_artifact(args["train_feature_artifact"])
train_x_path = train_x_artifact.file()

# train y
train_y_artifact = run.use_artifact(args["train_target_artifact"])
train_y_path = train_y_artifact.file()

# validation x
val_x_artifact = run.use_artifact(args["val_feature_artifact"])
val_x_path = val_x_artifact.file()

# validation y
val_y_artifact = run.use_artifact(args["val_target_artifact"])
val_y_path = val_y_artifact.file()

# unpacking the artifacts
train_x = joblib.load(train_x_path)
train_y = joblib.load(train_y_path)
val_x = joblib.load(val_x_path)
val_y = joblib.load(val_y_path)
# Out:
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221017_011154-1nnmsys9</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/1nnmsys9" target="_blank">gentle-bee-7</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 17-10-2022 01:11:56 Downloading the train and validation data

# %%
logger.info("Train x: {}".format(train_x.shape))
logger.info("Train y: {}".format(train_y.shape))
logger.info("Validation x: {}".format(val_x.shape))
logger.info("Validation y: {}".format(val_y.shape))
# Out:
# 17-10-2022 01:11:58 Train x: (1687, 3072)
# 17-10-2022 01:11:58 Train y: (1687,)
# 17-10-2022 01:11:58 Validation x: (563, 3072)
# 17-10-2022 01:11:58 Validation y: (563,)

# %% [markdown]
# ## Step 03: Encoder

# %%
# encode the labels as integers
le = LabelEncoder()
train_y = le.fit_transform(train_y)

val_y = le.transform(val_y)

# %%
# train a MLP classifier
logger.info("[INFO] training MLP classifier...")
model = MLPClassifier(hidden_layer_sizes=(100,100), activation='relu', solver='adam')
model.fit(train_x, train_y)
# Out:
# 17-10-2022 01:11:58 [INFO] training MLP classifier...
# MLPClassifier(hidden_layer_sizes=(100, 100))

# %%
logger.info("Dumping the model and encoder artifacts to the disk")

# Save the artifacts using joblib
joblib.dump(le, args["encoder"])
joblib.dump(model, args["inference_model"])
# Out:
# 17-10-2022 01:12:33 Dumping the model and encoder artifacts to the disk
# ['model']

# %%
# encoder artifact
artifact = wandb.Artifact(args["encoder"],
                          type="INFERENCE_MODEL",
                          description="A json file representing the target encoder"
                          )

logger.info("Logging the target encoder artifact")
artifact.add_file(args["encoder"])
run.log_artifact(artifact)
# Out:
# 17-10-2022 01:12:33 Logging the target encoder artifact

# %%
# inference model artifact
artifact = wandb.Artifact(args["inference_model"],
                          type="INFERENCE_MODEL",
                          description="A json file representing the inference model"
                          )

logger.info("Logging the inference model artifact")
artifact.add_file(args["inference_model"])
run.log_artifact(artifact)
# Out:
# 17-10-2022 01:12:33 Logging the inference model artifact

# %% [markdown]
# ## Step 04: Sweep (hyperparameter tuning)

# %% [markdown]
# ### Sweep setup

# %% [markdown]
# ℹ️ [Reference](https://docs.wandb.ai/guides/sweeps/define-sweep-configuration)

# %% [markdown]
# **Sweep configuration structure**
#
# Sweep configurations are nested; keys can have, as their values, further keys. The top-level keys are listed and briefly described below, and then detailed in the following section.
#
# | Top-Level Key | Description                                         |
# |---------------|-----------------------------------------------------|
# | **program**       | (required) Training script to run.                  |
# | **method**        | (required) Specify the <br>search strategy.         |
# | **parameters**    | (required) Specify <br>parameters bounds to search. |
#
# <br>
#
# **Search type methods**
#
# The following list describes hyperparameter search methods. Specify the search strategy with the **method**:
#
# - **grid**  – Iterate over every combination of hyperparameter values. Can be computationally costly.
# - **random**  – Choose a random set of hyperparameter values on each iteration based on provided distributions.
# - **bayes** – Create a probabilistic model of a metric score as a function of the hyperparameters, and choose parameters with high probability of improving the metric.
# <br>
#
# **Metric**
#
# Describes the metric to optimize. This metric should be logged **explicitly** to W&B by your training script.
#
# | Key    | Description |
# |--------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **name**   | Name of the metric to optimize.|
# | **goal**   | Either minimize or  maximize (Default is <br>minimize.|
# | **target** | Goal value for the metric you're optimizing. <br>When any run in the sweep achieves that target value,<br> the sweep's state will be set to finished. <br>This means all agents with active runs will <br>finish those jobs, but no new runs will <br>be launched in the sweep. |

# %%
# Configure the sweep 
sweep_config = {
    'name': 'sweep_mlp',
    'method': 'grid', 
    'metric': {
      'name': 'accuracy',
      'goal': 'maximize'   
    },
    'parameters': {
        'hidden_layer_sizes': {
            "values":[(100,100), (200, 200)],
        },
        'activation': {
            'values': ['relu']
        },
        'solver': {
            'values': ['adam']
        },
        'learning_rate' : {
            'values': ['constant','adaptive']
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project=args['project_name'])
# Out:
# Create sweep with ID: 13ezjnkq
# Sweep URL: https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq

# %% [markdown]
# ### Training

# %%
def train():
    with wandb.init() as run:
        # create codecarbon tracker
        # codecarbon is too much verbose, change the log level for more info
        # tracker = EmissionsTracker(log_level="critical")
        # tracker.start()
        model = MLPClassifier(hidden_layer_sizes=run.config.hidden_layer_sizes,
                              activation=run.config.activation,
                              solver=run.config.solver, 
                              learning_rate=run.config.learning_rate)
        # training
        logger.info("Training")
        model.fit(train_x,train_y)

        # infering
        logger.info("Infering")
        predict = model.predict(val_x)

        # get co2 emissions from tracker
        # "CO2 emission (in Kg)"
        # emissions = tracker.stop()

        # Evaluation Metrics
        logger.info("Evaluation metrics")
        fbeta = fbeta_score(val_y, 
                            predict, 
                            beta=1, 
                            zero_division=1,
                            average='weighted')
        precision = precision_score(val_y, 
                                    predict, 
                                    zero_division=1,
                                    average='weighted')
        recall = recall_score(val_y, 
                              predict, 
                              zero_division=1,
                              average='weighted')

        acc = accuracy_score(val_y, predict)

        logger.info("Test Accuracy: {}".format(acc))
        logger.info("Test Precision: {}".format(precision))
        logger.info("Test Recall: {}".format(recall))
        logger.info("Test F1: {}".format(fbeta))

        run.summary["Acc"] = acc
        run.summary["Precision"] = precision
        run.summary["Recall"] = recall
        run.summary["F1"] = fbeta

        # energy unit is kWh
        # run.summary["Energy_Consumed"] = tracker.final_emissions_data.energy_consumed
        # run.summary["Energy_RAM"] = tracker.final_emissions_data.ram_energy
        # run.summary["Energy_GPU"] = tracker.final_emissions_data.gpu_energy
        # run.summary["Energy_CPU"] = tracker.final_emissions_data.cpu_energy
        # # kg
        # run.summary["CO2_Emissions"] = tracker.final_emissions_data.emissions

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_id: the sweep_id to run - this was returned above by wandb.sweep()
#     – function: function that defines your model architecture and trains it
wandb.agent(sweep_id = sweep_id, function=train)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: Agent Starting Run: gql8t2iw with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221017_011242-gql8t2iw</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/gql8t2iw" target="_blank">leafy-sweep-1</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq</a>
# 17-10-2022 01:12:44 Training
# 17-10-2022 01:12:57 Infering
# 17-10-2022 01:12:57 Evaluation metrics
# 17-10-2022 01:12:57 Test Accuracy: 0.5062166962699822
# 17-10-2022 01:12:57 Test Precision: 0.5330622895729342
# 17-10-2022 01:12:57 Test Recall: 0.5062166962699822
# 17-10-2022 01:12:57 Test F1: 0.48593099954641217
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.008 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.047015…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.50622</td></tr><tr><td>F1</td><td>0.48593</td></tr><tr><td>Precision</td><td>0.53306</td></tr><tr><td>Recall</td><td>0.50622</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">leafy-sweep-1</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/gql8t2iw" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/gql8t2iw</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221017_011242-gql8t2iw/logs</code>
# wandb: Agent Starting Run: bhf46haj with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221017_011308-bhf46haj</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/bhf46haj" target="_blank">lunar-sweep-2</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq</a>
# 17-10-2022 01:13:09 Training
# 17-10-2022 01:13:23 Infering
# 17-10-2022 01:13:23 Evaluation metrics
# 17-10-2022 01:13:23 Test Accuracy: 0.5523978685612788
# 17-10-2022 01:13:23 Test Precision: 0.5609992494978712
# 17-10-2022 01:13:23 Test Recall: 0.5523978685612788
# 17-10-2022 01:13:23 Test F1: 0.5495677769739736
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.289764…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.5524</td></tr><tr><td>F1</td><td>0.54957</td></tr><tr><td>Precision</td><td>0.561</td></tr><tr><td>Recall</td><td>0.5524</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lunar-sweep-2</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/bhf46haj" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/bhf46haj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221017_011308-bhf46haj/logs</code>
# wandb: Agent Starting Run: s3iru5ro with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [200, 200]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221017_011334-s3iru5ro</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/s3iru5ro" target="_blank">breezy-sweep-3</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq</a>
# 17-10-2022 01:13:35 Training
# 17-10-2022 01:13:56 Infering
# 17-10-2022 01:13:56 Evaluation metrics
# 17-10-2022 01:13:56 Test Accuracy: 0.5630550621669627
# 17-10-2022 01:13:56 Test Precision: 0.5615217916491777
# 17-10-2022 01:13:56 Test Recall: 0.5630550621669627
# 17-10-2022 01:13:56 Test F1: 0.5392526841521542
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.56306</td></tr><tr><td>F1</td><td>0.53925</td></tr><tr><td>Precision</td><td>0.56152</td></tr><tr><td>Recall</td><td>0.56306</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">breezy-sweep-3</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/s3iru5ro" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/s3iru5ro</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221017_011334-s3iru5ro/logs</code>
# wandb: Agent Starting Run: dhywl3p2 with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [200, 200]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221017_011405-dhywl3p2</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/dhywl3p2" target="_blank">leafy-sweep-4</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/13ezjnkq</a>
# 17-10-2022 01:14:06 Training
# 17-10-2022 01:14:29 Infering
# 17-10-2022 01:14:29 Evaluation metrics
# 17-10-2022 01:14:29 Test Accuracy: 0.5310834813499112
# 17-10-2022 01:14:29 Test Precision: 0.5566116741651531
# 17-10-2022 01:14:29 Test Recall: 0.5310834813499112
# 17-10-2022 01:14:29 Test F1: 0.5265627623120022
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.53108</td></tr><tr><td>F1</td><td>0.52656</td></tr><tr><td>Precision</td><td>0.55661</td></tr><tr><td>Recall</td><td>0.53108</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">leafy-sweep-4</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/dhywl3p2" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/dhywl3p2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221017_011405-dhywl3p2/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
# Error in callback <function _WandbInit._pause_backend at 0x7f32f63008c0> (for post_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _pause_backend(self)
#     392                 res = self.run.log_code(root=None)
#     393                 logger.info("saved code: %s", res)
# --> 394             self.backend.interface.publish_pause()
#     395
#     396     def _resume_backend(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_pause(self)
#     634     def publish_pause(self) -> None:
#     635         pause = pb.PauseRequest()
# --> 636         self._publish_pause(pause)
#     637
#     638     @abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_pause(self, pause)
#     306     def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     307         rec = self._make_request(pause=pause)
# --> 308         self._publish(rec)
#     309
#     310     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      49     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      50         self._assign(record)
# ---> 51         self._sock_client.send_record_publish(record)
#      52
#      53     def _communicate_async(self, rec: "pb.Record", local: bool = None) -> MessageFuture:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     219         server_req = spb.ServerRequest()
#     220         server_req.record_publish.CopyFrom(record)
# --> 221         self.send_server_request(server_req)
#     222
#     223     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
# --> 155         self._send_message(msg)
#     156
#     157     def send_server_response(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     150         header = struct.pack("<BI", ord("W"), raw_size)
#     151         with self._lock:
# --> 152             self._sendall_with_error_handle(header + data)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
run.finish()
# Out:
# Error in callback <function _WandbInit._resume_backend at 0x7f326ad263b0> (for pre_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     397         if self.backend is not None:
#     398             logger.info("resuming backend")
# --> 399             self.backend.interface.publish_resume()
#     400
#     401     def _jupyter_teardown(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     642     def publish_resume(self) -> None:
#     643         resume = pb.ResumeRequest()
# --> 644         self._publish_resume(resume)
#     645
#     646     @abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_resume(self, resume)
#     310     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     311         rec = self._make_request(resume=resume)
# --> 312         self._publish(rec)
#     313
#     314     def _publish_run(self, run: pb.RunRecord) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      49     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      50         self._assign(record)
# ---> 51         self._sock_client.send_record_publish(record)
#      52
#      53     def _communicate_async(self, rec: "pb.Record", local: bool = None) -> MessageFuture:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     219         server_req = spb.ServerRequest()
#     220         server_req.record_publish.CopyFrom(record)
# --> 221         self.send_server_request(server_req)
#     222
#     223     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
# --> 155         self._send_message(msg)
#     156
#     157     def send_server_response(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     150         header = struct.pack("<BI", ord("W"), raw_size)
#     151         with self._lock:
# --> 152             self._sendall_with_error_handle(header + data)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# <ipython-input-35-7da56333b3d5> in <module>
# ----> 1 run.finish()
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in wrapper(self, *args, **kwargs)
#     290                     return cls.Dummy()
#     291
# --> 292             return func(self, *args, **kwargs)
#     293
#     294         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in wrapper(self, *args, **kwargs)
#     253                     raise e
#     254                 cls._is_attaching = ""
# --> 255             return func(self, *args, **kwargs)
#     256
#     257         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in finish(self, exit_code, quiet)
#    1737             quiet: Set to true to minimize log output
#    1738         """
# -> 1739         return self._finish(exit_code, quiet)
#    1740
#    1741     def _finish(self, exit_code: int = None, quiet: Optional[bool] = None) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in _finish(self, exit_code, quiet)
#    1743             self._quiet = quiet
#    1744         with telemetry.context(run=self) as tel:
# -> 1745             tel.feature.finish = True
#    1746         logger.info(f"finishing run {self._get_path()}")
#    1747         # detach jupyter hooks / others that needs to happen before backend shutdown
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/telemetry.py in __exit__(self, exctype, excinst, exctb)
#      38         if not self._run:
#      39             return
# ---> 40         self._run._telemetry_callback(self._obj)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in _telemetry_callback(self, telem_obj)
#     606         self._telemetry_obj.MergeFrom(telem_obj)
#     607         self._telemetry_obj_dirty = True
# --> 608         self._telemetry_flush()
#     609
#     610     def _telemetry_flush(self) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_run.py in _telemetry_flush(self)
#     617             if serialized == self._telemetry_obj_flushed:
#     618                 return
# --> 619             self._backend.interface._publish_telemetry(self._telemetry_obj)
#     620             self._telemetry_obj_flushed = serialized
#     621             self._telemetry_obj_dirty = False
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_telemetry(self, telem)
#      95     def _publish_telemetry(self, telem: tpb.TelemetryRecord) -> None:
#      96         rec = self._make_record(telemetry=telem)
# ---> 97         self._publish(rec)
#      98
#      99     def _make_stats(self, stats_dict: dict) -> pb.StatsRecord:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      49     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      50         self._assign(record)
# ---> 51         self._sock_client.send_record_publish(record)
#      52
#      53     def _communicate_async(self, rec: "pb.Record", local: bool = None) -> MessageFuture:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     219         server_req = spb.ServerRequest()
#     220         server_req.record_publish.CopyFrom(record)
# --> 221         self.send_server_request(server_req)
#     222
#     223     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
# --> 155         self._send_message(msg)
#     156
#     157     def send_server_response(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     150         header = struct.pack("<BI", ord("W"), raw_size)
#     151         with self._lock:
# --> 152             self._sendall_with_error_handle(header + data)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# Error in callback <function _WandbInit._pause_backend at 0x7f326ad26440> (for post_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/backcall/backcall.py in adapted(*args, **kwargs)
#     102                 kwargs.pop(name)
#     103 #            print(args, kwargs, unmatched_pos, cut_positional, unmatched_kw)
# --> 104             return callback(*args, **kwargs)
#     105
#     106         return adapted
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _pause_backend(self)
#     392                 res = self.run.log_code(root=None)
#     393                 logger.info("saved code: %s", res)
# --> 394             self.backend.interface.publish_pause()
#     395
#     396     def _resume_backend(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_pause(self)
#     634     def publish_pause(self) -> None:
#     635         pause = pb.PauseRequest()
# --> 636         self._publish_pause(pause)
#     637
#     638     @abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_pause(self, pause)
#     306     def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     307         rec = self._make_request(pause=pause)
# --> 308         self._publish(rec)
#     309
#     310     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      49     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      50         self._assign(record)
# ---> 51         self._sock_client.send_record_publish(record)
#      52
#      53     def _communicate_async(self, rec: "pb.Record", local: bool = None) -> MessageFuture:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     219         server_req = spb.ServerRequest()
#     220         server_req.record_publish.CopyFrom(record)
# --> 221         self.send_server_request(server_req)
#     222
#     223     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
# --> 155         self._send_message(msg)
#     156
#     157     def send_server_response(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     150         header = struct.pack("<BI", ord("W"), raw_size)
#     151         with self._lock:
# --> 152             self._sendall_with_error_handle(header + data)
#     153
#     154     def send_server_request(self, msg: Any) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     128             start_time = time.monotonic()
#     129             try:
# --> 130                 sent = self._sock.send(data)
#     131                 # sent equal to 0 indicates a closed socket
#     132                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
