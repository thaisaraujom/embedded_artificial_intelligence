# %% [markdown]
# # Your First Image Classifier: Using MLP to Classify Images
# # Train

# %% [markdown]
# The purpose of this dataset is to correctly classify an image as containing a dog, cat, or panda.
# Containing only 3,000 images, the Animals dataset is meant to be another **introductory** dataset
# that we can quickly train a MLP model and obtain a comparative results.
#
#
# Let's take the following steps:
#
# 1. Encoding target variable
# 2. Training the MLP model
# 3. Export the model and the encoder object
#
# <center><img width="900" src="https://drive.google.com/uc?export=view&id=1haMB_Zt6Et9q9sPHxfuR4g3FT5QRXlTI"></center>

# %% [markdown]
# ## Step 01: Setup

# %% [markdown]
# Start out by installing the experiment tracking library and setting up your free W&B account:
#
#
# *   **pip install wandb** – Install the W&B library
# *   **import wandb** – Import the wandb library
# *   **wandb login** – Login to your W&B account so you can log all your metrics in one place

# %%
# !pip install wandb -qU

# %%
# a Python package for tracking the carbon emissions produced by various
# kinds of computer programs, from straightforward algorithms to deep neural networks.
# !pip install codecarbon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: codecarbon in /usr/local/lib/python3.7/dist-packages (2.1.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from codecarbon) (1.3.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.7/dist-packages (from codecarbon) (8.0.0)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (from codecarbon) (0.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from codecarbon) (2.23.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from codecarbon) (5.4.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from codecarbon) (7.1.2)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.7/dist-packages (from codecarbon) (11.4.1)
# Requirement already satisfied: arrow in /usr/local/lib/python3.7/dist-packages (from codecarbon) (1.2.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from arrow->codecarbon) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from arrow->codecarbon) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.0->arrow->codecarbon) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->codecarbon) (2022.4)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->codecarbon) (1.21.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->codecarbon) (2.10)

# %% [markdown]
# ### Import Packages

# %%
# import the necessary packages
from imutils import paths
import logging
import os
import cv2
import numpy as np
import joblib
from codecarbon import EmissionsTracker
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import fbeta_score, precision_score, recall_score, accuracy_score
import wandb

# %%
wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: thaisaraujom. Use `wandb login --relogin` to force relogin
# True

# %%
# configure logging
# reference for a logging obj
logger = logging.getLogger()

# set level of logging
logger.setLevel(logging.INFO)

# create handlers
c_handler = logging.StreamHandler()
c_format = logging.Formatter(fmt="%(asctime)s %(message)s",datefmt='%d-%m-%Y %H:%M:%S')
c_handler.setFormatter(c_format)

# add handler to the logger
logger.handlers[0] = c_handler

# %% [markdown]
# ## Step 02 Basic configuration and download artifacts

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
  "project_name": "mlp_classifier",
  "train_feature_artifact": "train_x:latest",
  "train_target_artifact": "train_y:latest",
  "val_feature_artifact": "val_x:latest",
  "val_target_artifact": "val_y:latest",
  "neighbors": 1,
  "jobs": -1,
  "encoder": "target_encoder",
  "inference_model": "model"
}

# %%
# open the W&B project created in the Fetch step
run = wandb.init(entity="thaisaraujom",project=args["project_name"], job_type="Train")

logger.info("Downloading the train and validation data")
# train x
train_x_artifact = run.use_artifact(args["train_feature_artifact"])
train_x_path = train_x_artifact.file()

# train y
train_y_artifact = run.use_artifact(args["train_target_artifact"])
train_y_path = train_y_artifact.file()

# validation x
val_x_artifact = run.use_artifact(args["val_feature_artifact"])
val_x_path = val_x_artifact.file()

# validation y
val_y_artifact = run.use_artifact(args["val_target_artifact"])
val_y_path = val_y_artifact.file()

# unpacking the artifacts
train_x = joblib.load(train_x_path)
train_y = joblib.load(train_y_path)
val_x = joblib.load(val_x_path)
val_y = joblib.load(val_y_path)
# Out:
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010142-j85bls0s</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/j85bls0s" target="_blank">glorious-valley-101</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 18-10-2022 01:01:44 Downloading the train and validation data

# %%
logger.info("Train x: {}".format(train_x.shape))
logger.info("Train y: {}".format(train_y.shape))
logger.info("Validation x: {}".format(val_x.shape))
logger.info("Validation y: {}".format(val_y.shape))
# Out:
# 18-10-2022 01:01:50 Train x: (1687, 3072)
# 18-10-2022 01:01:50 Train y: (1687,)
# 18-10-2022 01:01:50 Validation x: (563, 3072)
# 18-10-2022 01:01:50 Validation y: (563,)

# %% [markdown]
# ## Step 03: Encoder

# %%
# encode the labels as integers
le = LabelEncoder()
train_y = le.fit_transform(train_y)

val_y = le.transform(val_y)

# %%
# train a MLP classifier
logger.info("[INFO] training MLP classifier...")
model = MLPClassifier(hidden_layer_sizes=(100,100), activation='relu', solver='adam')
model.fit(train_x, train_y)
# Out:
# 18-10-2022 01:01:50 [INFO] training MLP classifier...
# MLPClassifier(hidden_layer_sizes=(100, 100))

# %%
logger.info("Dumping the model and encoder artifacts to the disk")

# Save the artifacts using joblib
joblib.dump(le, args["encoder"])
joblib.dump(model, args["inference_model"])
# Out:
# 18-10-2022 01:02:14 Dumping the model and encoder artifacts to the disk
# ['model']

# %%
# encoder artifact
artifact = wandb.Artifact(args["encoder"],
                          type="INFERENCE_MODEL",
                          description="A json file representing the target encoder"
                          )

logger.info("Logging the target encoder artifact")
artifact.add_file(args["encoder"])
run.log_artifact(artifact)
# Out:
# 18-10-2022 01:02:14 Logging the target encoder artifact

# %%
# inference model artifact
artifact = wandb.Artifact(args["inference_model"],
                          type="INFERENCE_MODEL",
                          description="A json file representing the inference model"
                          )

logger.info("Logging the inference model artifact")
artifact.add_file(args["inference_model"])
run.log_artifact(artifact)
# Out:
# 18-10-2022 01:02:14 Logging the inference model artifact

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">glorious-valley-101</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/j85bls0s" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/j85bls0s</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010142-j85bls0s/logs</code>

# %% [markdown]
# ## Step 04: Sweep (hyperparameter tuning)

# %% [markdown]
# ### Sweep setup

# %% [markdown]
# ℹ️ [Reference](https://docs.wandb.ai/guides/sweeps/define-sweep-configuration)

# %% [markdown]
# **Sweep configuration structure**
#
# Sweep configurations are nested; keys can have, as their values, further keys. The top-level keys are listed and briefly described below, and then detailed in the following section.
#
# | Top-Level Key | Description                                         |
# |---------------|-----------------------------------------------------|
# | **program**       | (required) Training script to run.                  |
# | **method**        | (required) Specify the <br>search strategy.         |
# | **parameters**    | (required) Specify <br>parameters bounds to search. |
#
# <br>
#
# **Search type methods**
#
# The following list describes hyperparameter search methods. Specify the search strategy with the **method**:
#
# - **grid**  – Iterate over every combination of hyperparameter values. Can be computationally costly.
# - **random**  – Choose a random set of hyperparameter values on each iteration based on provided distributions.
# - **bayes** – Create a probabilistic model of a metric score as a function of the hyperparameters, and choose parameters with high probability of improving the metric.
# <br>
#
# **Metric**
#
# Describes the metric to optimize. This metric should be logged **explicitly** to W&B by your training script.
#
# | Key    | Description |
# |--------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **name**   | Name of the metric to optimize.|
# | **goal**   | Either minimize or  maximize (Default is <br>minimize.|
# | **target** | Goal value for the metric you're optimizing. <br>When any run in the sweep achieves that target value,<br> the sweep's state will be set to finished. <br>This means all agents with active runs will <br>finish those jobs, but no new runs will <br>be launched in the sweep. |

# %%
# Configure the sweep 
sweep_config = {
    'method': 'random', 
    'metric': {
      'name': 'accuracy',
      'goal': 'maximize'   
    },
    'parameters': {
        'hidden_layer_sizes': {
            "values":[(100,100), (100, 100)],
        },
        'activation': {
            'values': ['relu']
        },
        'solver': {
            'values': ['adam']
        },
        'learning_rate' : {
            'values': ['constant','adaptive']
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project=args['project_name'])
# Out:
# Create sweep with ID: 31jxcg4q
# Sweep URL: https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q

# %% [markdown]
# ### Training

# %%
def train():
    with wandb.init() as run:
        # create codecarbon tracker
        # codecarbon is too much verbose, change the log level for more info
        tracker = EmissionsTracker(log_level="critical")
        tracker.start()
        model = MLPClassifier(hidden_layer_sizes=run.config.hidden_layer_sizes,
                              activation=run.config.activation,
                              solver=run.config.solver, 
                              learning_rate=run.config.learning_rate)
        # training
        logger.info("Training")
        model.fit(train_x,train_y)

        # infering
        logger.info("Infering")
        predict = model.predict(val_x)

        # get co2 emissions from tracker
        # "CO2 emission (in Kg)"
        emissions = tracker.stop()

        # Evaluation Metrics
        logger.info("Evaluation metrics")
        fbeta = fbeta_score(val_y, 
                            predict, 
                            beta=1, 
                            zero_division=1,
                            average='weighted')
        precision = precision_score(val_y, 
                                    predict, 
                                    zero_division=1,
                                    average='weighted')
        recall = recall_score(val_y, 
                              predict, 
                              zero_division=1,
                              average='weighted')

        acc = accuracy_score(val_y, predict)

        logger.info("Val Accuracy: {}".format(acc))
        logger.info("Val Precision: {}".format(precision))
        logger.info("Val Recall: {}".format(recall))
        logger.info("Val F1: {}".format(fbeta))

        run.summary["Acc"] = acc
        run.summary["Precision"] = precision
        run.summary["Recall"] = recall
        run.summary["F1"] = fbeta

        # energy unit is kWh
        run.summary["Energy_Consumed"] = tracker.final_emissions_data.energy_consumed
        run.summary["Energy_RAM"] = tracker.final_emissions_data.ram_energy
        run.summary["Energy_GPU"] = tracker.final_emissions_data.gpu_energy
        run.summary["Energy_CPU"] = tracker.final_emissions_data.cpu_energy
        # kg
        run.summary["CO2_Emissions"] = tracker.final_emissions_data.emissions

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_id: the sweep_id to run - this was returned above by wandb.sweep()
#     – function: function that defines your model architecture and trains it
wandb.agent(sweep_id = sweep_id, function=train, count=10)
# Out:
# wandb: Agent Starting Run: gnc1mltc with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010228-gnc1mltc</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/gnc1mltc" target="_blank">feasible-sweep-1</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:02:32 Training
# 18-10-2022 01:02:36 Infering
# 18-10-2022 01:02:37 Evaluation metrics
# 18-10-2022 01:02:37 Val Accuracy: 0.4422735346358792
# 18-10-2022 01:02:37 Val Precision: 0.5943067785176246
# 18-10-2022 01:02:37 Val Recall: 0.4422735346358792
# 18-10-2022 01:02:37 Val F1: 0.44720845551983757
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.44227</td></tr><tr><td>CO2_Emissions</td><td>5e-05</td></tr><tr><td>Energy_CPU</td><td>6e-05</td></tr><tr><td>Energy_Consumed</td><td>8e-05</td></tr><tr><td>Energy_GPU</td><td>1e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.44721</td></tr><tr><td>Precision</td><td>0.59431</td></tr><tr><td>Recall</td><td>0.44227</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">feasible-sweep-1</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/gnc1mltc" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/gnc1mltc</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010228-gnc1mltc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vdtxiah8 with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010254-vdtxiah8</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/vdtxiah8" target="_blank">sleek-sweep-2</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:02:57 Training
# 18-10-2022 01:03:10 Infering
# 18-10-2022 01:03:10 Evaluation metrics
# 18-10-2022 01:03:10 Val Accuracy: 0.49023090586145646
# 18-10-2022 01:03:10 Val Precision: 0.5113086912000974
# 18-10-2022 01:03:10 Val Recall: 0.49023090586145646
# 18-10-2022 01:03:10 Val F1: 0.42336705541449793
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.49023</td></tr><tr><td>CO2_Emissions</td><td>0.00012</td></tr><tr><td>Energy_CPU</td><td>0.00015</td></tr><tr><td>Energy_Consumed</td><td>0.00019</td></tr><tr><td>Energy_GPU</td><td>3e-05</td></tr><tr><td>Energy_RAM</td><td>2e-05</td></tr><tr><td>F1</td><td>0.42337</td></tr><tr><td>Precision</td><td>0.51131</td></tr><tr><td>Recall</td><td>0.49023</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sleek-sweep-2</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/vdtxiah8" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/vdtxiah8</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010254-vdtxiah8/logs</code>
# wandb: Agent Starting Run: 8d51moq7 with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010321-8d51moq7</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/8d51moq7" target="_blank">blooming-sweep-3</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:03:25 Training
# 18-10-2022 01:03:32 Infering
# 18-10-2022 01:03:32 Evaluation metrics
# 18-10-2022 01:03:32 Val Accuracy: 0.3907637655417407
# 18-10-2022 01:03:32 Val Precision: 0.5807930827839765
# 18-10-2022 01:03:32 Val Recall: 0.3907637655417407
# 18-10-2022 01:03:32 Val F1: 0.3808553769388578
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050425…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.39076</td></tr><tr><td>CO2_Emissions</td><td>7e-05</td></tr><tr><td>Energy_CPU</td><td>9e-05</td></tr><tr><td>Energy_Consumed</td><td>0.00012</td></tr><tr><td>Energy_GPU</td><td>2e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.38086</td></tr><tr><td>Precision</td><td>0.58079</td></tr><tr><td>Recall</td><td>0.39076</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">blooming-sweep-3</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/8d51moq7" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/8d51moq7</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010321-8d51moq7/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: r8qc56cv with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010349-r8qc56cv</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/r8qc56cv" target="_blank">legendary-sweep-4</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:03:53 Training
# 18-10-2022 01:04:01 Infering
# 18-10-2022 01:04:01 Evaluation metrics
# 18-10-2022 01:04:01 Val Accuracy: 0.49733570159857904
# 18-10-2022 01:04:01 Val Precision: 0.5676147641186415
# 18-10-2022 01:04:01 Val Recall: 0.49733570159857904
# 18-10-2022 01:04:01 Val F1: 0.49205670119926226
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.49734</td></tr><tr><td>CO2_Emissions</td><td>8e-05</td></tr><tr><td>Energy_CPU</td><td>9e-05</td></tr><tr><td>Energy_Consumed</td><td>0.00012</td></tr><tr><td>Energy_GPU</td><td>2e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.49206</td></tr><tr><td>Precision</td><td>0.56761</td></tr><tr><td>Recall</td><td>0.49734</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">legendary-sweep-4</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/r8qc56cv" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/r8qc56cv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010349-r8qc56cv/logs</code>
# wandb: Agent Starting Run: e6l7ih10 with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010412-e6l7ih10</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/e6l7ih10" target="_blank">amber-sweep-5</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:04:16 Training
# 18-10-2022 01:04:29 Infering
# 18-10-2022 01:04:29 Evaluation metrics
# 18-10-2022 01:04:29 Val Accuracy: 0.5150976909413855
# 18-10-2022 01:04:29 Val Precision: 0.5204372982097921
# 18-10-2022 01:04:29 Val Recall: 0.5150976909413855
# 18-10-2022 01:04:29 Val F1: 0.5105568082195162
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.5151</td></tr><tr><td>CO2_Emissions</td><td>0.00012</td></tr><tr><td>Energy_CPU</td><td>0.00015</td></tr><tr><td>Energy_Consumed</td><td>0.0002</td></tr><tr><td>Energy_GPU</td><td>3e-05</td></tr><tr><td>Energy_RAM</td><td>2e-05</td></tr><tr><td>F1</td><td>0.51056</td></tr><tr><td>Precision</td><td>0.52044</td></tr><tr><td>Recall</td><td>0.5151</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">amber-sweep-5</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/e6l7ih10" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/e6l7ih10</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010412-e6l7ih10/logs</code>
# wandb: Agent Starting Run: 9s760goi with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010439-9s760goi</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/9s760goi" target="_blank">light-sweep-6</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:04:43 Training
# 18-10-2022 01:04:48 Infering
# 18-10-2022 01:04:48 Evaluation metrics
# 18-10-2022 01:04:48 Val Accuracy: 0.566607460035524
# 18-10-2022 01:04:48 Val Precision: 0.5951154529307283
# 18-10-2022 01:04:48 Val Recall: 0.566607460035524
# 18-10-2022 01:04:48 Val F1: 0.47929460707688526
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050436…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.56661</td></tr><tr><td>CO2_Emissions</td><td>5e-05</td></tr><tr><td>Energy_CPU</td><td>6e-05</td></tr><tr><td>Energy_Consumed</td><td>8e-05</td></tr><tr><td>Energy_GPU</td><td>1e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.47929</td></tr><tr><td>Precision</td><td>0.59512</td></tr><tr><td>Recall</td><td>0.56661</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">light-sweep-6</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/9s760goi" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/9s760goi</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010439-9s760goi/logs</code>
# wandb: Agent Starting Run: ag224kuh with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010500-ag224kuh</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/ag224kuh" target="_blank">worthy-sweep-7</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:05:04 Training
# 18-10-2022 01:05:15 Infering
# 18-10-2022 01:05:15 Evaluation metrics
# 18-10-2022 01:05:15 Val Accuracy: 0.5257548845470693
# 18-10-2022 01:05:15 Val Precision: 0.5407653076960758
# 18-10-2022 01:05:15 Val Recall: 0.5257548845470693
# 18-10-2022 01:05:15 Val F1: 0.4992027769596058
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050409…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.52575</td></tr><tr><td>CO2_Emissions</td><td>0.00011</td></tr><tr><td>Energy_CPU</td><td>0.00013</td></tr><tr><td>Energy_Consumed</td><td>0.00018</td></tr><tr><td>Energy_GPU</td><td>3e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.4992</td></tr><tr><td>Precision</td><td>0.54077</td></tr><tr><td>Recall</td><td>0.52575</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">worthy-sweep-7</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/ag224kuh" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/ag224kuh</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010500-ag224kuh/logs</code>
# wandb: Agent Starting Run: 0w4adt1b with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: adaptive
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010527-0w4adt1b</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/0w4adt1b" target="_blank">generous-sweep-8</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:05:31 Training
# 18-10-2022 01:05:37 Infering
# 18-10-2022 01:05:37 Evaluation metrics
# 18-10-2022 01:05:37 Val Accuracy: 0.5115452930728241
# 18-10-2022 01:05:37 Val Precision: 0.5534158381582893
# 18-10-2022 01:05:37 Val Recall: 0.5115452930728241
# 18-10-2022 01:05:37 Val F1: 0.47867477478209824
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.51155</td></tr><tr><td>CO2_Emissions</td><td>6e-05</td></tr><tr><td>Energy_CPU</td><td>7e-05</td></tr><tr><td>Energy_Consumed</td><td>0.0001</td></tr><tr><td>Energy_GPU</td><td>2e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.47867</td></tr><tr><td>Precision</td><td>0.55342</td></tr><tr><td>Recall</td><td>0.51155</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">generous-sweep-8</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/0w4adt1b" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/0w4adt1b</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010527-0w4adt1b/logs</code>
# wandb: Agent Starting Run: 8b0v0r3u with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010547-8b0v0r3u</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/8b0v0r3u" target="_blank">ethereal-sweep-9</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:05:52 Training
# 18-10-2022 01:06:02 Infering
# 18-10-2022 01:06:02 Evaluation metrics
# 18-10-2022 01:06:02 Val Accuracy: 0.566607460035524
# 18-10-2022 01:06:02 Val Precision: 0.5731509323590956
# 18-10-2022 01:06:02 Val Recall: 0.566607460035524
# 18-10-2022 01:06:02 Val F1: 0.5656522817366586
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.56661</td></tr><tr><td>CO2_Emissions</td><td>0.0001</td></tr><tr><td>Energy_CPU</td><td>0.00011</td></tr><tr><td>Energy_Consumed</td><td>0.00015</td></tr><tr><td>Energy_GPU</td><td>3e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.56565</td></tr><tr><td>Precision</td><td>0.57315</td></tr><tr><td>Recall</td><td>0.56661</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-sweep-9</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/8b0v0r3u" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/8b0v0r3u</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010547-8b0v0r3u/logs</code>
# wandb: Agent Starting Run: jgg6hf6t with config:
# wandb: 	activation: relu
# wandb: 	hidden_layer_sizes: [100, 100]
# wandb: 	learning_rate: constant
# wandb: 	solver: adam
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/content/wandb/run-20221018_010614-jgg6hf6t</code>
# Syncing run <strong><a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/jgg6hf6t" target="_blank">sunny-sweep-10</a></strong> to <a href="https://wandb.ai/thaisaraujom/mlp_classifier" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/sweeps/31jxcg4q</a>
# 18-10-2022 01:06:18 Training
# 18-10-2022 01:06:28 Infering
# 18-10-2022 01:06:28 Evaluation metrics
# 18-10-2022 01:06:28 Val Accuracy: 0.477797513321492
# 18-10-2022 01:06:28 Val Precision: 0.5451274580240218
# 18-10-2022 01:06:28 Val Recall: 0.477797513321492
# 18-10-2022 01:06:28 Val F1: 0.4711604505548896
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050425…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Acc</td><td>0.4778</td></tr><tr><td>CO2_Emissions</td><td>9e-05</td></tr><tr><td>Energy_CPU</td><td>0.00011</td></tr><tr><td>Energy_Consumed</td><td>0.00015</td></tr><tr><td>Energy_GPU</td><td>2e-05</td></tr><tr><td>Energy_RAM</td><td>1e-05</td></tr><tr><td>F1</td><td>0.47116</td></tr><tr><td>Precision</td><td>0.54513</td></tr><tr><td>Recall</td><td>0.4778</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sunny-sweep-10</strong>: <a href="https://wandb.ai/thaisaraujom/mlp_classifier/runs/jgg6hf6t" target="_blank">https://wandb.ai/thaisaraujom/mlp_classifier/runs/jgg6hf6t</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221018_010614-jgg6hf6t/logs</code>

# %%
run.finish()
